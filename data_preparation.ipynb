# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("csv/utk.csv")

# %%
df.head()
# Out:
#                                 filename  age  gender  race
# 0  23_1_0_20170116221715630.jpg.chip.jpg   23       1     0
# 1  16_1_0_20170109213044006.jpg.chip.jpg   16       1     0
# 2  36_1_4_20170112234015846.jpg.chip.jpg   36       1     4
# 3  28_0_0_20170116210101534.jpg.chip.jpg   28       0     0
# 4  48_0_0_20170104182220669.jpg.chip.jpg   48       0     0

# %%
df_train, df_temp = train_test_split(df, train_size=0.8, stratify=df.age, random_state=42)
df_test, df_valid = train_test_split(df_temp, train_size=0.5, stratify=df_temp.age, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_train, df_temp = train_test_split(df, train_size=0.8, stratify=df.age, random_state=42)
#       2 df_test, df_valid = train_test_split(df_temp, train_size=0.5, stratify=df_temp.age, random_state=42)
#
# File c:\Users\Clarence Berganio\Documents\GitHub\project-null\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\Clarence Berganio\Documents\GitHub\project-null\.venv\Lib\site-packages\sklearn\model_selection\_split.py:2945, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2941         CVClass = ShuffleSplit
#    2943     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2945     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2947 xp, _, device = get_namespace_and_device(arrays[0])
#    2948 train, test = move_to(train, test, xp=xp, device=device)
#
# File c:\Users\Clarence Berganio\Documents\GitHub\project-null\.venv\Lib\site-packages\sklearn\model_selection\_split.py:1928, in BaseShuffleSplit.split(self, X, y, groups)
#    1898 """Generate indices to split data into training and test set.
#    1899
#    1900 Parameters
#    (...)   1925 to an integer.
#    1926 """
#    1927 X, y, groups = indexable(X, y, groups)
# -> 1928 for train, test in self._iter_indices(X, y, groups):
#    1929     yield train, test
#
# File c:\Users\Clarence Berganio\Documents\GitHub\project-null\.venv\Lib\site-packages\sklearn\model_selection\_split.py:2346, in StratifiedShuffleSplit._iter_indices(self, X, y, groups)
#    2344 if np.min(class_counts) < 2:
#    2345     too_few_classes = classes[class_counts < 2].tolist()
# -> 2346     raise ValueError(
#    2347         "The least populated classes in y have only 1"
#    2348         " member, which is too few. The minimum"
#    2349         " number of groups for any class cannot"
#    2350         " be less than 2. Classes with too few"
#    2351         " members are: %s" % (too_few_classes)
#    2352     )
#    2354 if n_train < n_classes:
#    2355     raise ValueError(
#    2356         "The train_size = %d should be greater or "
#    2357         "equal to the number of classes = %d" % (n_train, n_classes)
#    2358     )
#
# ValueError: The least populated classes in y have only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2. Classes with too few members are: [103, 111]
