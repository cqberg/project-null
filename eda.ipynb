# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("whitegrid")

# %%
df = pd.read_csv("csv/utk.csv")

# %%
df.head()
# Out:
#                                 filename  age  gender  race
# 0  23_1_0_20170116221715630.jpg.chip.jpg   23       1     0
# 1  16_1_0_20170109213044006.jpg.chip.jpg   16       1     0
# 2  36_1_4_20170112234015846.jpg.chip.jpg   36       1     4
# 3  28_0_0_20170116210101534.jpg.chip.jpg   28       0     0
# 4  48_0_0_20170104182220669.jpg.chip.jpg   48       0     0

# %%
plt.figure(figsize=(10,8))
sns.histplot(df, x="age", kde=True)
plt.xlabel("Age")
plt.show()

# %%
race_map = {
    0: "white",
    1: "black",
    2: "asian",
    3: "indian",
    4: "others"
}

df["race_label"] = df["race"].map(race_map)

plt.figure(figsize=(10,8))
sns.countplot(df, x="race_label")
plt.xlabel("Race")
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 8))
gender_count = df["gender"].value_counts()
sns.countplot(df, x="gender", hue="gender", ax=ax[0])
ax[1].pie(gender_count, labels=gender_count.index, autopct="%1.1f%%")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(df, x="race_label", hue="gender")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df, x="age", hue="gender", gap=0.1)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df, x="age", hue="race_label", gap=0.1)
plt.tight_layout()
plt.show()
